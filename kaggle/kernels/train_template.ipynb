# %% [markdown]
# # RSNA Knee — Train Template (deprecated pointer)
#
# This stub is kept for discoverability. The Phase 1 offline-submittable baseline lives in:
#
# - Source: `notebooks/03_phase1_image_baseline.ipynb`
# - Kaggle: `kaggle/train/train.ipynb` (generated)
# - Sync: `python scripts/sync_kaggle_train.py --push`
#
# Do **not** use git-clone / pip-install here for submissions — scoring runs with **internet OFF**.

# %%
print("Use notebooks/03_phase1_image_baseline.ipynb + scripts/sync_kaggle_train.py")
